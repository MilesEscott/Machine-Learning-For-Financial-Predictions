# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from metrics import *

# %%
testSet = pd.read_csv("C:/Users/Miles/Documents/ml_project_cv/Data/testSet.csv", index_col=0, parse_dates=True)
testSet

# %%
buyAndHoldStrategy = pd.DataFrame(1, index=testSet.index, columns=["Prediction"])
buyAndHoldStrategy.to_csv("C:/Users/Miles/Documents/ml_project_cv/Predictions/BuyAndHoldStrategy.csv")
buyAndHoldStrategy

# %%
# Momentum strategy if 20-day return > 20

momentumStrategyPrediction = ((testSet["20-Day Returns"] > 0).shift(1)).fillna(0).astype(int).to_frame(name="Prediction")
momentumStrategyPrediction.to_csv("C:/Users/Miles/Documents/ml_project_cv/Predictions/MomentumStrategy.csv")
momentumStrategyPrediction
